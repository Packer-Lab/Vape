# %%
# %run ../setup_notebook.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# notebook specific imports
from utils import cacher
import pickle
from termcolor import cprint

# %%
pkl_path = os.path.join(path_to_vape, 'run_pkls')
if not os.path.exists(pkl_path):
    os.mkdir(pkl_path)

# %%
pkl_path
# Out:
# '/home/jrowland/Documents/code/Vape/run_pkls'

# %%
mouse_id = 'J063'
run_numbers = [8,9,10,11,12,13,14]
for run_number in run_numbers:
    
    cprint('\n\nRun Number {}\n'.format(run_number), attrs=['bold'])
    
    cacher.main(mouse_id, run_number, pkl_path,   
                reprocess=True, reload=False, do_s2p=False, do_flu_preprocess=False)
# Out:
# Run Number 8
#
# /home/jrowland/Documents/code/Vape/run_pkls/J063/run8.pkl
# False
# /home/jrowland/mnt/qnap/Data/2019-12-12
# ['/home/jrowland/mnt/qnap/Data/2019-12-12/blimp/2019-12-12-185359', '/home/jrowland/mnt/qnap/Data/2019-12-12/naparm/2019-12-12_J063_naparm_002']
# ['/home/jrowland/mnt/qnap/Data/2019-12-12/J063-2019-12-12-185905.txt', '/home/jrowland/mnt/qnap/Data/2019-12-12/2019-12-12_J063_t002.paq', '/home/jrowland/mnt/qnap/Data/2019-12-12/J063-2019-12-12-184740.txt']
# ['/home/jrowland/mnt/qnap/Data/2019-12-12/2019-12-12_J063_t-002']
# ['/home/jrowland/mnt/qnap/Data/2019-12-12/2019-12-12_J063_t-003']
# ['/home/jrowland/mnt/qnap/Data/2019-12-12/2019-12-12_J063_t-004']
# ['/home/jrowland/mnt/qnap/Data/2019-12-12/2019-12-12_J063_t-005']
# ['/home/jrowland/mnt/qnap/Data/2019-12-12/2019-12-12_J063_t-006']
# ['/home/jrowland/mnt/qnap/Data/2019-12-12/2019-12-12_J063_t-007']
# Importing data file: J063-2019-12-12-185905.txt
# pycontrol J063-2019-12-12-185905 successfully matched to blimp folder 2019-12-12-185359
# pycontrol J063-2019-12-12-184740.txt rsync successfully matched to paq 2019-12-12_J063_t002.paq
# Importing data file: J063-2019-12-12-184740.txt
# prereward J063-2019-12-12-184740.txt rsync successfully matched to paq 2019-12-12_J063_t002.paq
#
# following tseries found:
# 2019-12-12_J063_t-002_Cycle00001_Ch3.tif
# 2019-12-12_J063_t-003_Cycle00001_Ch3.tif
# 2019-12-12_J063_t-004_Cycle00001_Ch3.tif
# 2019-12-12_J063_t-005_Cycle00001_Ch3.tif
# 2019-12-12_J063_t-006_Cycle00001_Ch3.tif
# 2019-12-12_J063_t-007_Cycle00001_Ch3.tif
#
#
# [[1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514]]
# obfov detected
#
#
# Run Number 9
#
# /home/jrowland/Documents/code/Vape/run_pkls/J063/run9.pkl
# False
# /home/jrowland/mnt/qnap/Data/2019-12-13
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/blimp/2019-12-13-194114', '/home/jrowland/mnt/qnap/Data/2019-12-13/naparm/2019-12-13_J063_naparm_002']
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/J063-2019-12-13-195535.txt', '/home/jrowland/mnt/qnap/Data/2019-12-13/2019-12-13_J063_t002.paq', '/home/jrowland/mnt/qnap/Data/2019-12-13/J063-2019-12-13-194600.txt']
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/2019-12-13_J063_t-002']
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/2019-12-13_J063_t-003']
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/2019-12-13_J063_t-004']
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/2019-12-13_J063_t-005']
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/2019-12-13_J063_t-006']
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/2019-12-13_J063_t-007']
# ['/home/jrowland/mnt/qnap/Data/2019-12-13/2019-12-13_J063_t-008']
# Importing data file: J063-2019-12-13-195535.txt
# pycontrol J063-2019-12-13-195535.txt successfully matched to blimp folder 2019-12-13-194114
# pycontrol J063-2019-12-13-194600.txt rsync successfully matched to paq 2019-12-13_J063_t002.paq
# Importing data file: J063-2019-12-13-194600.txt
# prereward J063-2019-12-13-194600.txt rsync successfully matched to paq 2019-12-13_J063_t002.paq
#
# following tseries found:
# 2019-12-13_J063_t-002_Cycle00001_Ch3.tif
# 2019-12-13_J063_t-003_Cycle00001_Ch3.tif
# 2019-12-13_J063_t-004_Cycle00001_Ch3.tif
# 2019-12-13_J063_t-005_Cycle00001_Ch3.tif
# 2019-12-13_J063_t-006_Cycle00001_Ch3.tif
# 2019-12-13_J063_t-007_Cycle00001_Ch3.tif
# 2019-12-13_J063_t-008_Cycle00001_Ch3.tif
#
#
# [[1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514]]
# obfov detected
#
#
# Run Number 10
#
# /home/jrowland/Documents/code/Vape/run_pkls/J063/run10.pkl
# False
# /home/jrowland/mnt/qnap/Data/2019-12-14
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/blimp/2019-12-14-124743', '/home/jrowland/mnt/qnap/Data/2019-12-14/naparm/2019-12-14_J063_naparm_002']
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/J063-2019-12-14-125156.txt', '/home/jrowland/mnt/qnap/Data/2019-12-14/2019-12-14_J063_t002.paq', '/home/jrowland/mnt/qnap/Data/2019-12-14/J063-2019-12-14-124118.txt']
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/2019-12-14_J063_t-002']
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/2019-12-14_J063_t-003']
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/2019-12-14_J063_t-004']
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/2019-12-14_J063_t-005']
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/2019-12-14_J063_t-006']
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/2019-12-14_J063_t-007']
# ['/home/jrowland/mnt/qnap/Data/2019-12-14/2019-12-14_J063_t-008']
# Importing data file: J063-2019-12-14-125156.txt
# pycontrol J063-2019-12-14-125156 successfully matched to blimp folder 2019-12-14-124743
# pycontrol J063-2019-12-14-124118.txt rsync successfully matched to paq 2019-12-14_J063_t002.paq
# Importing data file: J063-2019-12-14-124118.txt
# prereward J063-2019-12-14-124118.txt rsync successfully matched to paq 2019-12-14_J063_t002.paq
#
# following tseries found:
# 2019-12-14_J063_t-002_Cycle00001_Ch3.tif
# 2019-12-14_J063_t-003_Cycle00001_Ch3.tif
# 2019-12-14_J063_t-004_Cycle00001_Ch3.tif
# 2019-12-14_J063_t-005_Cycle00001_Ch3.tif
# 2019-12-14_J063_t-006_Cycle00001_Ch3.tif
# 2019-12-14_J063_t-007_Cycle00001_Ch3.tif
# 2019-12-14_J063_t-008_Cycle00001_Ch3.tif
#
#
# [[1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514]]
# obfov detected
#
#
# Run Number 11
#
# /home/jrowland/Documents/code/Vape/run_pkls/J063/run11.pkl
# False
# /home/jrowland/mnt/qnap/Data/2019-12-16
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/blimp/2019-12-16-211458', '/home/jrowland/mnt/qnap/Data/2019-12-16/naparm/2019-12-16_j063_NAPARM_001']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/J063-2019-12-16-212100.txt', '/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-14_J063_t003.paq', '/home/jrowland/mnt/qnap/Data/2019-12-16/J063-2019-12-16-211013.txt']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-003']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-004']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-005']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-006']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-007']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-008']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-009']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-010']
# ['/home/jrowland/mnt/qnap/Data/2019-12-16/2019-12-16_J063_t-011']
# Importing data file: J063-2019-12-16-212100.txt
# pycontrol J063-2019-12-16-212100 successfully matched to blimp folder 2019-12-16-211458
# pycontrol J063-2019-12-16-211013.txt rsync successfully matched to paq 2019-12-14_J063_t003.paq
# Importing data file: J063-2019-12-16-211013.txt
# prereward J063-2019-12-16-211013.txt rsync successfully matched to paq 2019-12-14_J063_t003.paq
#
# following tseries found:
# 2019-12-16_J063_t-003_Cycle00001_Ch3.tif
# 2019-12-16_J063_t-004_Cycle00001_Ch3.tif
# 2019-12-16_J063_t-005_Cycle00001_Ch3.tif
# 2019-12-16_J063_t-006_Cycle00001_Ch3.tif
# 2019-12-16_J063_t-007_Cycle00001_Ch3.tif
# 2019-12-16_J063_t-008_Cycle00001_Ch3.tif
# 2019-12-16_J063_t-009_Cycle00001_Ch3.tif
# 2019-12-16_J063_t-010_Cycle00001_Ch3.tif
# 2019-12-16_J063_t-011_Cycle00001_Ch3.tif
#
#
# [[1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514], [1024, 514]]
# obfov detected
#
#
# Run Number 12
#
# /home/jrowland/Documents/code/Vape/run_pkls/J063/run12.pkl
# False
# /home/jrowland/mnt/qnap/Data/2019-12-17
# ['/home/jrowland/mnt/qnap/Data/2019-12-17/blimp/2019-12-17-161315', '/home/jrowland/mnt/qnap/Data/2019-12-17/naparm/2019-12-17_j063_NAPARM_002']
# ['/home/jrowland/mnt/qnap/Data/2019-12-17/J063-2019-12-17-161936.txt', '/home/jrowland/mnt/qnap/Data/2019-12-17/2019-12-17_J063_t002.paq', '/home/jrowland/mnt/qnap/Data/2019-12-17/J063-2019-12-17-160620.txt']
# ['/home/jrowland/mnt/qnap/Data/2019-12-17/2019-12-17_J063_t-002']
# ['/home/jrowland/mnt/qnap/Data/2019-12-17/2019-12-17_J063_t-003']
# ['/home/jrowland/mnt/qnap/Data/2019-12-17/2019-12-17_J063_t-004']
# ['/home/jrowland/mnt/qnap/Data/2019-12-17/2019-12-17_J063_t-005']
# ['/home/jrowland/mnt/qnap/Data/2019-12-17/2019-12-17_J063_t-006']
# Importing data file: J063-2019-12-17-161936.txt
# pycontrol J063-2019-12-17-161936 successfully matched to blimp folder 2019-12-17-161315
# pycontrol J063-2019-12-17-160620.txt rsync successfully matched to paq 2019-12-17_J063_t002.paq
# Importing data file: J063-2019-12-17-160620.txt
# prereward J063-2019-12-17-160620.txt rsync successfully matched to paq 2019-12-17_J063_t002.paq
#
# following tseries found:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-46e892e3f6e5> in <module>
#       6
#       7     cacher.main(mouse_id, run_number, pkl_path,
# ----> 8                 reprocess=True, reload=False, do_s2p=False, do_flu_preprocess=False)
#
# ~/Documents/code/Vape/utils/cacher.py in main(mouse_id, run_number, pkl_path, do_s2p, reprocess, reload, do_flu_preprocess)
#     240             tiff_list.append(tiff[0])
#     241         elif len(tiff) > 2:
# --> 242             raise valueerror('more than two tiffs, likely '
#     243                              'mpt conversion failed')
#     244
#
# NameError: name 'valueerror' is not defined

# %%
# J048 run28 has an unexplained offset in some of the 150 cell trials
mouse_id = 'J048'
run_numbers = [27,28,29,30,32]
# run_numbers = [29]

for run_number in run_numbers::
    
    cprint('\n\nRun Number {}\n'.format(run_number), attrs=['bold'])
    
    cacher.main(mouse_id, run_number, pkl_path,   
                reprocess=True, reload=True, do_s2p=False)
# Out:
# Run Number 27
#
# Importing data file: J048-2019-08-02-162212.txt
# pycontrol J048-2019-08-02-162212 successfully matched to blimp folder 2019-08-02-161927
# pycontrol J048-2019-08-02-160921.txt rsync successfully matched to paq 2019-08-02_J048_t003.paq
# Importing data file: J048-2019-08-02-160921.txt
# prereward J048-2019-08-02-160921.txt rsync successfully matched to paq 2019-08-02_J048_t003.paq
#
# Following tseries found:
# 2019-08-02_J048_t-003_Ch3.tif
# 2019-08-02_J048_t-004_Ch3.tif
# 2019-08-02_J048_t-005_Ch3.tif
# 2019-08-02_J048_t-006_Ch3.tif
# 2019-08-02_J048_t-007_Ch3.tif
# 2019-08-02_J048_t-008_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 2101 traces labelled as cells
# Loading 2101 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# WARNING: Could not find all tseries chunks in frame clock, check this
# Total number of frames detected in clock is 47437
# These are the lengths of the tseries from spreadsheet [5287, 7527, 7527, 13548, 13548, 911]
# The total length of the tseries spreasheets is 48348
# The missing chunk is 911 long
# A single tseries in the spreadsheet list is missing, number 6
# WARNING: Fluoresence matrix does not match frame clock shape, check this
#
#
# Run Number 28
#
# Importing data file: J048-2019-08-03-142954.txt
# pycontrol J048-2019-08-03-142954 successfully matched to blimp folder 2019-08-03-142743
# pycontrol J048-2019-08-03-141324.txt rsync successfully matched to paq 2019-08-03_J048_t002.paq
# Importing data file: J048-2019-08-03-141324.txt
# prereward J048-2019-08-03-141324.txt rsync successfully matched to paq 2019-08-03_J048_t002.paq
#
# Following tseries found:
# 2019-08-03_J048_t-003_Ch3.tif
# 2019-08-03_J048_t-004_Ch3.tif
# 2019-08-03_J048_t-005_Ch3.tif
# 2019-08-03_J048_t-006_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 2194 traces labelled as cells
# Loading 2194 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# All tseries chunks found in frame clock
# Fluorescence matrix shape matches recorded frame clock
#
#
# Run Number 29
#
# Importing data file: J048-2019-08-05-193452.txt
# pycontrol J048-2019-08-05-193452 successfully matched to blimp folder 2019-08-05-193211
# pycontrol J048-2019-08-05-192348.txt rsync successfully matched to paq 2019-08-05_J048_t006.paq
# Importing data file: J048-2019-08-05-192348.txt
# prereward J048-2019-08-05-192348.txt rsync successfully matched to paq 2019-08-05_J048_t006.paq
#
# Following tseries found:
# 2019-08-05_J048_t-014_Ch3.tif
# 2019-08-05_J048_t-015_Ch3.tif
# 2019-08-05_J048_t-016_Ch3.tif
# 2019-08-05_J048_t-017_Ch3.tif
# 2019-08-05_J048_t-018_Ch3.tif
# 2019-08-05_J048_t-019_Ch3.tif
# 2019-08-05_J048_t-020_Ch3.tif
# 2019-08-05_J048_t-021_Ch3.tif
# 2019-08-05_J048_t-022_Ch3.tif
# 2019-08-05_J048_t-023_Cycle00001_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 1531 traces labelled as cells
# Loading 1531 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# WARNING: Could not find all tseries chunks in frame clock, check this
# Total number of frames detected in clock is 114755
# These are the lengths of the tseries from spreadsheet [13548, 13548, 13548, 13548, 12393, 13548, 13548, 13548, 7526, 3119]
# The total length of the tseries spreasheets is 117874
# The missing chunk is 3119 long
# A single tseries in the spreadsheet list is missing, number 10
# WARNING: Fluoresence matrix does not match frame clock shape, check this
#
#
# Run Number 30
#
# Importing data file: J048-2019-08-06-220759.txt
# pycontrol J048-2019-08-06-220759 successfully matched to blimp folder 2019-08-06-220601
# pycontrol J048-2019-08-06-220115.txt rsync successfully matched to paq 2019-08-06_J048_t004.paq
# Importing data file: J048-2019-08-06-220115.txt
# prereward J048-2019-08-06-220115.txt rsync successfully matched to paq 2019-08-06_J048_t004.paq
#
# Following tseries found:
# 2019-08-06_J048_t-004_Ch3.tif
# 2019-08-06_J048_t-005_Ch3.tif
# 2019-08-06_J048_t-006_Ch3.tif
# 2019-08-06_J048_t-007_Ch3.tif
# 2019-08-06_J048_t-008_Ch3.tif
# 2019-08-06_J048_t-009_Ch3.tif
# 2019-08-06_J048_t-010_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 2085 traces labelled as cells
# Loading 2085 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# All tseries chunks found in frame clock
# Fluorescence matrix shape matches recorded frame clock
#
#
# Run Number 32
#
# Importing data file: J048-2019-08-08-225429.txt
# pycontrol J048-2019-08-08-225429 successfully matched to blimp folder 2019-08-08-224828
# pycontrol J048-2019-08-08-224615.txt rsync successfully matched to paq 2019-08-08_J048_t003.paq
# Importing data file: J048-2019-08-08-224615.txt
# prereward J048-2019-08-08-224615.txt rsync successfully matched to paq 2019-08-08_J048_t003.paq
#
# Following tseries found:
# 2019-08-08_J048_t-004_Ch3.tif
# 2019-08-08_J048_t-005_Ch3.tif
# 2019-08-08_J048_t-006_Ch3.tif
# 2019-08-08_J048_t-007_Ch3.tif
# 2019-08-08_J048_t-008_Ch3.tif
# 2019-08-08_J048_t-009_Ch3.tif
# 2019-08-08_J048_t-010_Ch3.tif
# 2019-08-08_J048_t-011_Ch3.tif
# 2019-08-08_J048_t-012_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 1972 traces labelled as cells
# Loading 1972 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# All tseries chunks found in frame clock
# Fluorescence matrix shape matches recorded frame clock

# %%
mouse_id = 'RL048'
run_numbers = [23, 24, 25, 28, 29]
# run_numbers = [24]

for run_number in run_numbers:
    
    cprint('\nRun Number {}\n'.format(run_number), attrs=['bold'])
    
    cacher.main(mouse_id, run_number, pkl_path,              
                reprocess=True, reload=True, do_s2p=False)
# Out:
# Run Number 23
#
# Importing data file: RL048-2019-08-02-182658.txt
# pycontrol RL048-2019-08-02-182658 successfully matched to blimp folder 2019-08-02-182445
# pycontrol RL048-2019-08-02-181715.txt rsync successfully matched to paq 2019-08-02_RL048_t003.paq
# Importing data file: RL048-2019-08-02-181715.txt
# prereward RL048-2019-08-02-181715.txt rsync successfully matched to paq 2019-08-02_RL048_t003.paq
#
# Following tseries found:
# 2019-08-02_RL048_t-003_Ch3.tif
# 2019-08-02_RL048_t-004_Ch3.tif
# 2019-08-02_RL048_t-005_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 3571 traces labelled as cells
# Loading 3571 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# All tseries chunks found in frame clock
# Fluorescence matrix shape matches recorded frame clock
#
# Run Number 24
#
# Importing data file: RL048-2019-08-03-125152.txt
# pycontrol RL048-2019-08-03-125152 successfully matched to blimp folder 2019-08-03-124909
# pycontrol RL048-2019-08-03-124034.txt rsync successfully matched to paq 2019-08-03_RL048_t002.paq
# Importing data file: RL048-2019-08-03-124034.txt
# prereward RL048-2019-08-03-124034.txt rsync successfully matched to paq 2019-08-03_RL048_t002.paq
#
# Following tseries found:
# 2019-08-03_RL048_t-004_Ch3.tif
# 2019-08-03_RL048_t-005_Ch3.tif
# 2019-08-03_RL048_t-006_Ch3.tif
# 2019-08-03_RL048_t-007_Ch3.tif
# 2019-08-03_RL048_t-008_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 3063 traces labelled as cells
# Loading 3063 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# WARNING: Could not find all tseries chunks in frame clock, check this
# Total number of frames detected in clock is 42501
# These are the lengths of the tseries from spreadsheet [7785, 7620, 13548, 13548, 11371]
# The total length of the tseries spreasheets is 53872
# The missing chunk is 11371 long
# A single tseries in the spreadsheet list is missing, number 5
# WARNING: Fluoresence matrix does not match frame clock shape, check this
#
# Run Number 25
#
# Importing data file: RL048-2019-08-05-225537.txt
# pycontrol RL048-2019-08-05-225537 successfully matched to blimp folder 2019-08-05-225251
# pycontrol RL048-2019-08-05-224535.txt rsync successfully matched to paq 2019-08-05_RL048_t002.paq
# Importing data file: RL048-2019-08-05-224535.txt
# prereward RL048-2019-08-05-224535.txt rsync successfully matched to paq 2019-08-05_RL048_t002.paq
#
# Following tseries found:
# 2019-08-05_RL048_t-002_Ch3.tif
# 2019-08-05_RL048_t-005_Ch3.tif
# 2019-08-05_RL048_t-006_Ch3.tif
# 2019-08-05_RL048_t-007_Ch3.tif
# 2019-08-05_RL048_t-008_Ch3.tif
# 2019-08-05_RL048_t-009_Ch3.tif
# 2019-08-05_RL048_t-010_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 2892 traces labelled as cells
# Loading 2892 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# All tseries chunks found in frame clock
# Fluorescence matrix shape matches recorded frame clock
#
# Run Number 28
#
# Importing data file: RL048-2019-08-08-210601.txt
# pycontrol RL048-2019-08-08-210601 successfully matched to blimp folder 2019-08-08-205953
# pycontrol RL048-2019-08-08-204528.txt rsync successfully matched to paq 2019-08-08_RL048_t003.paq
# Importing data file: RL048-2019-08-08-204528.txt
# prereward RL048-2019-08-08-204528.txt rsync successfully matched to paq 2019-08-08_RL048_t003.paq
#
# Following tseries found:
# 2019-08-08_RL048_t-003_Ch3.tif
# 2019-08-08_RL048_t-005_Ch3.tif
# 2019-08-08_RL048_t-006_Ch3.tif
# 2019-08-08_RL048_t-007_Ch3.tif
# 2019-08-08_RL048_t-008_Ch3.tif
# 2019-08-08_RL048_t-009_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 2727 traces labelled as cells
# Loading 2727 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# All tseries chunks found in frame clock
# Fluorescence matrix shape matches recorded frame clock
#
# Run Number 29
#
# Importing data file: RL048-2019-08-09-184320.txt
# pycontrol RL048-2019-08-09-184320 successfully matched to blimp folder 2019-08-09-183644
# pycontrol RL048-2019-08-09-183502.txt rsync successfully matched to paq 2019-08-09_RL048_t002.paq
# Importing data file: RL048-2019-08-09-183502.txt
# prereward RL048-2019-08-09-183502.txt rsync successfully matched to paq 2019-08-09_RL048_t002.paq
#
# Following tseries found:
# 2019-08-09_RL048_t-002_Ch3.tif
# 2019-08-09_RL048_t-003_Ch3.tif
# 2019-08-09_RL048_t-004_Ch3.tif
# 2019-08-09_RL048_t-005_Ch3.tif
# 2019-08-09_RL048_t-006_Ch3.tif
#
#
# Bafov detected
# Already done s2p
#
# Loading 1992 traces labelled as cells
# Loading 1992 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# All tseries chunks found in frame clock
# Fluorescence matrix shape matches recorded frame clock
