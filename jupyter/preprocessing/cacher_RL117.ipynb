# %%
# %run ../setup_notebook.ipynb

# %%
# notebook specific imports
from utils import cacher
import pickle
from termcolor import cprint

# %%
pkl_path = os.path.join(path_to_vape, 'run_pkls')
if not os.path.exists(pkl_path):
    os.mkdir(pkl_path)

# %%
mouse_id = 'RL117'

# Run 28 yields an untraceable assertion error in a pyx file for numpy fft
# run_numbers = [28]
# Blimp error that i don't understand
# run_numbers = [29]

run_numbers = [30]


for run_number in run_numbers:
    
    cprint('\n\nRun Number {}\n'.format(run_number), attrs=['bold'])
    
    cacher.main(mouse_id, run_number, pkl_path,   
                reprocess=True, reload=True, do_s2p=True, do_flu_preprocess=True)
# Out:
# Run Number 30
#
# /home/jrowland/mnt/qnap/Data/2021-03-10
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/blimp/2021-03-10-164539']
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/naparm/2021-03-10_RL117_002']
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/RL117-2021-03-10-165849.txt', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-002.paq', '/home/jrowland/mnt/qnap/Data/2021-03-10/RL117-2021-03-10-164400.txt']
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-002']
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-003']
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-004']
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-005']
# Importing data file: RL117-2021-03-10-165849.txt
# pycontrol RL117-2021-03-10-165849 successfully matched to blimp folder 2021-03-10-164539
# pycontrol RL117-2021-03-10-164400.txt rsync successfully matched to paq 2021-03-10_RL117_t-002.paq
# Importing data file: RL117-2021-03-10-164400.txt
# prereward RL117-2021-03-10-164400.txt rsync successfully matched to paq 2021-03-10_RL117_t-002.paq
#
# following tseries found:
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-002', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-003', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-004', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-005']
#
#
# [[1024, 514], [1024, 514], [1024, 514], [1024, 514]]
# obfov detected
# Data path is /home/jrowland/mnt/qnap/Data/2021-03-10
# s2p path is /home/jrowland/mnt/qnap/Data/2021-03-10/suite2p/RL117
# Bad frames calculated and saved to /home/jrowland/mnt/qnap/Data/2021-03-10
# Bad frames calculated and saved to /home/jrowland/mnt/qnap/Data/2021-03-10/suite2p/RL117
# Bad frames calculated and saved to /home/jrowland/mnt/qnap/Data/2021-03-10/suite2p/RL117
# Running s2p on tseries printed above
#
# {'data_path': ['/home/jrowland/mnt/qnap/Data/2021-03-10'], 'look_one_level_down': True, 'diameter': 11, 'tiff_list': ['/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-002/2021-03-10_RL117_t-002_Cycle00001_Ch3.tif', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-003/2021-03-10_RL117_t-003_Cycle00001_Ch3.tif', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-004/2021-03-10_RL117_t-004_Cycle00001_Ch3.tif', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-005/2021-03-10_RL117_t-005_Cycle00001_Ch3.tif'], 'nplanes': 1, 'fs': 30, 'save_folder': '/home/jrowland/mnt/qnap/Data/2021-03-10/suite2p/RL117', 'roidetect': True, 'spikedetect': False}
# /home/jrowland/mnt/qnap/Data/2021-03-10/suite2p/RL117/plane0
# ['/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-002/2021-03-10_RL117_t-002_Cycle00001_Ch3.tif', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-003/2021-03-10_RL117_t-003_Cycle00001_Ch3.tif', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-004/2021-03-10_RL117_t-004_Cycle00001_Ch3.tif', '/home/jrowland/mnt/qnap/Data/2021-03-10/2021-03-10_RL117_t-005/2021-03-10_RL117_t-005_Cycle00001_Ch3.tif']
# ** Found 4 tifs - converting to binary **
# 10000 frames of binary, time 145.64 sec.
# 20000 frames of binary, time 384.73 sec.
# time 2123.87 sec. Wrote tifs to binaries for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# ----------- REGISTRATION
# registering 97856 frames
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-0710ad19005f> in <module>
#      14
#      15     cacher.main(mouse_id, run_number, pkl_path,
# ---> 16                 reprocess=True, reload=True, do_s2p=True, do_flu_preprocess=True)
#
# ~/Documents/code/Vape/utils/cacher.py in main(mouse_id, run_number, pkl_path, do_s2p, reprocess, reload, do_flu_preprocess)
#     348                             run_number, save_folder))
#     349
# --> 350         opsEnd=run_s2p(ops=ops,db=db)
#     351
#     352         with open('/home/jrowland/mnt/qnap/suite2p_report.txt', 'a') as f:
#
# ~/Documents/code/suite2p/suite2p/run_s2p.py in run_s2p(ops, db)
#     232             t11=time.time()
#     233             print('----------- REGISTRATION')
# --> 234             ops1[ipl] = register.register_binary(ops1[ipl]) # register binary
#     235             np.save(fpathops1, ops1) # save ops1
#     236             print('----------- Total %0.2f sec'%(time.time()-t11))
#
# ~/Documents/code/suite2p/suite2p/registration/register.py in register_binary(ops, refImg, raw)
#     363             refImg, bidi = reference.compute_reference_image(ops, raw_file_align)
#     364         else:
# --> 365             refImg, bidi = reference.compute_reference_image(ops, reg_file_align)
#     366         ops['bidiphase'] = bidi
#     367         print('Reference frame, %0.2f sec.'%(time.time()-t0))
#
# ~/Documents/code/suite2p/suite2p/registration/reference.py in compute_reference_image(ops, bin_file)
#     132         bidiphase.shift(frames, bidi)
#     133     refImg = pick_initial_reference(frames)
# --> 134     refImg = iterative_alignment(ops, frames, refImg)
#     135     return refImg, bidi
#     136
#
# ~/Documents/code/suite2p/suite2p/registration/reference.py in iterative_alignment(ops, frames, refImg)
#      79     for iter in range(0,niter):
#      80         ops['refImg'] = refImg
# ---> 81         maskMul, maskOffset, cfRefImg = rigid.phasecorr_reference(refImg, ops)
#      82         freg, ymax, xmax, cmax, yxnr = register.compute_motion_and_shift(frames,
#      83                                                     [maskMul, maskOffset, cfRefImg], ops)
#
# ~/Documents/code/suite2p/suite2p/registration/rigid.py in phasecorr_reference(refImg0, ops)
#      48                             (next_fast_len(Ly), next_fast_len(Lx))))
#      49     else:
# ---> 50         cfRefImg   = np.conj(fft2(refImg))
#      51
#      52     absRef     = np.absolute(cfRefImg)
#
# mkl_fft/_pydfti.pyx in mkl_fft._pydfti.fft2()
#
# mkl_fft/_pydfti.pyx in mkl_fft._pydfti._fftnd_impl()
#
# mkl_fft/_pydfti.pyx in mkl_fft._pydfti.iter_complementary()
#
# mkl_fft/_pydfti.pyx in mkl_fft._pydfti._direct_fftnd()
#
# AssertionError:
