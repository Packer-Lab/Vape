# %%
# %run ../setup_notebook.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
for p in sys.path:
    print(p)
# Out:
# /home/clean_python/code/Vape/jupyter/preprocessing
# /home/clean_python/anaconda3/envs/suite2p/lib/python37.zip
# /home/clean_python/anaconda3/envs/suite2p/lib/python3.7
# /home/clean_python/anaconda3/envs/suite2p/lib/python3.7/lib-dynload
#
# /home/clean_python/anaconda3/envs/suite2p/lib/python3.7/site-packages
# /home/clean_python/anaconda3/envs/suite2p/lib/python3.7/site-packages/IPython/extensions
# /home/clean_python/.ipython
# /home/clean_python/code/Vape/
# /home/clean_python/code/Vape/utils
# ..
# /home/clean_python/Documents/code/suite2p
# /home/clean_python/code/Vape/
# /home/clean_python/code/Vape/utils

# %%
# notebook specific imports
from utils import cacher
import pickle
from termcolor import cprint
import json

# %%
pkl_path = os.path.join(path_to_vape, 'run_pkls')
if not os.path.exists(pkl_path):
    os.mkdir(pkl_path)

# %%
mouse_id = 'RL117'

# run_numbers = [28]

# Had to make fie changes, made Baks
run_numbers = [29]

# run_numbers = [30] 


for run_number in run_numbers:
    
    cprint('\n\nRun Number {}\n'.format(run_number), attrs=['bold'])
    
    cacher.main(mouse_id, run_number, pkl_path,   
                reprocess=True, reload=True, do_s2p=False, do_flu_preprocess=True)
# Out:
# Run Number 29
#
# /home/jrowland/mnt/qnap/Data/2021-03-09
# ['/home/jrowland/mnt/qnap/Data/2021-03-09/blimp/2021-03-09-145935']
# ['/home/jrowland/mnt/qnap/Data/2021-03-09/naparm/2021-03-09_RL117_003']
# ['/home/jrowland/mnt/qnap/Data/2021-03-09/RL117-2021-03-09-150915.txt', '/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-002.paq', '/home/jrowland/mnt/qnap/Data/2021-03-09/RL117-2021-03-09-145731.txt']
# ['/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-005']
# ['/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-006']
# ['/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-007']
# ['/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-008']
# Importing data file: RL117-2021-03-09-150915.txt
# pycontrol RL117-2021-03-09-150915 successfully matched to blimp folder 2021-03-09-145935
# pycontrol RL117-2021-03-09-145731.txt rsync successfully matched to paq 2021-03-09_RL117_t-002.paq
# Importing data file: RL117-2021-03-09-145731.txt
# prereward RL117-2021-03-09-145731.txt rsync successfully matched to paq 2021-03-09_RL117_t-002.paq
#
# following tseries found:
# ['/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-005', '/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-006', '/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-007', '/home/jrowland/mnt/qnap/Data/2021-03-09/2021-03-09_RL117_t-008']
#
#
# [[1024, 514], [1024, 514], [1024, 514], [1024, 514]]
# obfov detected
# Data path is /home/jrowland/mnt/qnap/Data/2021-03-09
# s2p path is /home/jrowland/mnt/qnap/Data/2021-03-09/suite2p/RL117
# /home/jrowland/mnt/qnap/Data/2021-03-09/suite2p/RL117/plane0
# loading 611 traces labelled as cells
# loading 611 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# All tseries chunks found in frame clock
# Fluorescence matrix shape matches recorded frame clock

# %%
# %debug
# Out:
# > /home/clean_python/code/Vape/utils/run_functions.py(440)jitter_tstart()
#     438 def jitter_tstart(run):
#     439     ''' requires spiral_start '''
# --> 440     return run.aligner.B_to_A(run.spiral_start) -  run.trial_start
#     441
#     442
#
# ipdb> q

# %%
## I used the below to figure out and debug the s1/s2 border code

# %%
# with open('/home/jrowland/Documents/code/Vape/s2_position.json') as json_file:
#     s1s2_border_json = json.load(json_file)i
    
# s1s2_border = s1s2_border_json[mouse][str(run_number)]

# # self.s2_bool = self.av_xpix > self.s1s2_border
# # self.s1_bool = np.logical_not(self.s2_bool)

# %%
# im = np.zeros((514,1024))

# ever_targeted = np.any(session.is_target, axis=(1,2))

# x1, y1, x2, y2 = s1s2_border
# plt.plot([x1, x2], [y1, y2])


# bool_ = ever_targeted
# bool_ = session.s2_bool
# bool_ = [True] *len(session.s1_bool)
# for x,y in zip(session.av_xpix[bool_], session.av_ypix[bool_]):
#     x = int(x)
#     y = int(y)
#     im[y-5:y+5, x-5:x+5] = 1

# plt.imshow(im)

# plt.axvline(700)
