# %% [markdown]
# ## Notebook for collecting metadata, processing imaging data through suite2p and analysing trial responses

# %%
# %run ./rob_setup_notebook.ipynb

import utils.interareal_analysis as ia
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Suite2p path: ['/home/rlees/anaconda3/envs/suite2p/lib/python3.7/site-packages/suite2p']
# qnap_path: /home/rlees/mnt/qnap
# qnap_data_path /home/rlees/mnt/qnap/Data
# pkl_folder: /home/rlees/mnt/qnap/pkl_files
# master_path: /home/rlees/mnt/qnap/master_pkl/master_obj.pkl
# fig_save_path: /home/rlees/mnt/qnap/Analysis/Figures
# stam_save_path: /home/rlees/mnt/qnap/Analysis/STA_movies
# s2_borders_path: /home/rlees/mnt/qnap/Analysis/S2_borders

# %% [markdown]
# ### Define sessions to run s2p or analysis on

# %%
ss_id = '1PgSXs6BVHe9dACWEydykucN74rirNfOY4Vr_AmLcCdY'
sheet_names = [
#     '2019-06-11_J048',
#     '2019-06-13_J052',
#     '2019-06-25_RL048',
#     '2019-07-15_RL052',
#     '2019-08-14_J058',
#     '2019-08-14_J059',
#     '2019-08-15_RL055',
#     '2019-11-14_J061',
#     '2019-11-14_J063',
#     '2019-11-15_J064',
#     '2019-11-18_J065',
#     '2020-02-27_RL075',
#     '2020-03-03_RL074',
#     '2020-03-05_RL070',
#     '2020-03-05_RL072',
#     '2020-03-12_RL070',
#     '2020-03-16_RL074',
#     '2020-03-19_RL075',
#     '2020-06-03_RL086',
#     '2020-06-08_RL086',
#     '2020-06-15_RL086',
#     '2020-09-03_RL091',
#     '2020-09-04_RL093',
#     '2020-09-08_RL099',
#     '2020-09-09_RL100',
#     '2020-09-14_RL101',
#     '2020-09-15_RL102',
#     '2020-09-16_RL103',
#     '2020-10-02_RL108',
#     '2020-10-12_RL109',
#     '2020-10-29_RL111',
#     '2020-12-10_RL115',
    '2021-01-06_RL120',
#     '2021-01-06_RL120_test',
    '2021-01-20_RL121',
    '2021-01-20_RL125', 
    '2021-01-20_RL124', 
    '2021-01-28_RL124', 
#     '2021-02-18_RL127', 
#     '2021-02-22_RL128', 
#     '2021-02-23_RL129', 
#     '2021-02-24_RL132', 
#     '2021-02-25_RL131', 
#     '2021-03-02_RL130'
              ]

# %% [markdown]
# ### Run s2p on defined sessions (commented-out to not overwrite data by accident)

# %%
# for sheet_name in sheet_names:
    
#     # Initialise the class
#     ses_obj = ia.interarealProcessing(ss_id, sheet_name, qnap_data_path)
    
#     # Run s2p on this experiment (if not already done)
#     ses_obj.s2pRun(tau=0.7) # tau = 0.7 for fast, 1.25 for slow
    
#     # Pickle the object output to save it for analysis
#     pkl_path = os.path.join(pkl_folder, sheet_name + '.pkl')
    
#     with open(pkl_path, 'wb') as f:
#         pickle.dump(ses_obj, f)

# %% [markdown]
# ### Run sessions through preprocessing pipeline (after s2p ROI curation)

# %%
trial_sig_calc = 'dff' # how to calculate trial significance ('dff' or 'dfsf' = change in f over std deviation of f)
prestim_sec = 2
poststim_sec = 10
test_sec = 1.5

for sheet_name in sheet_names:
    
    # Initialise the class
    ses_obj = ia.interarealProcessing(ss_id, sheet_name, qnap_data_path)
    
    # Get the range of frames that are attributed to each experiment (from the concatenated t-series)
    ses_obj.getFrameRanges()
    
    # Process the s2p data (after manual curation)
    ses_obj.photostim_r.s2pAnalysis(s2_borders_path, prestim_sec, poststim_sec, test_sec, trial_sig_calc)
    ses_obj.photostim_s.s2pAnalysis(s2_borders_path, prestim_sec, poststim_sec, test_sec, trial_sig_calc)
    ses_obj.whisker_stim.s2pAnalysis(s2_borders_path, prestim_sec, poststim_sec, test_sec, trial_sig_calc)
    
    # Add sham photostim metadata
    if ses_obj.spont.n_frames > 0:
        ses_obj.addShamPhotostim()
        
    ses_obj.spont.s2pAnalysis(s2_borders_path, prestim_sec, poststim_sec, test_sec, trial_sig_calc)
    
    ses_obj.whiskerTargets()
    
    # Pickle the object output to save it for analysis
    pkl_path = os.path.join(pkl_folder, sheet_name + '.pkl')
    
    with open(pkl_path, 'wb') as f:
        pickle.dump(ses_obj, f)
# Out:
# ================================================================
# Fetching paths and stim types for: 2021-01-06_RL120
# ================================================================
#
# Umbrella folder: /home/rlees/mnt/qnap/Data/2021-01-06
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-002']
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-002.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003.paq']
#
# Experimental sorted_paths = (array(['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003.paq'],
#       dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003.paq'],
#       dtype='<U70'), array([], dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-002',
#        '/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-002.paq'],
#       dtype='<U70'))
#
# ----------------------------------------------------------------
# Obtaining metadata for pr stim: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321425986596
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# Obtaining metadata for ps stim: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321425986596
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-003.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# No metadata for this w stim experiment
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Obtaining metadata for none stim: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-002
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321653432857
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
#
# Calculating frame ranges...
# ______________________________________________________________________
#
# Processing s2p data for pr experiment type
# ______________________________________________________________________
#
# loading 477 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  89
# ______________________________________________________________________
#
# Processing s2p data for ps experiment type
# ______________________________________________________________________
#
# loading 477 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  89
# ______________________________________________________________________
#
# No s2p data for w in this session
# ______________________________________________________________________
#
# ----------------------------------------------------------------
# Obtaining sham metadata for spont: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-002
# ----------------------------------------------------------------
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_NAPARM_002/2021-01-06_RL120_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-06/RL120/2021-01-06_RL120_t-002.paq
# total stim duration (frames): 4
# ______________________________________________________________________
#
# Processing s2p data for none experiment type
# ______________________________________________________________________
#
# loading 477 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  89
#
# ================================================================
# Fetching paths and stim types for: 2021-01-20_RL121
# ================================================================
#
# Umbrella folder: /home/rlees/mnt/qnap/Data/2021-01-20
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-002.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003.paq']
#
# Experimental sorted_paths = (array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003.paq'],
#       dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003.paq'],
#       dtype='<U70'), array([], dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-002.paq'],
#       dtype='<U70'))
#
# ----------------------------------------------------------------
# Obtaining metadata for pr stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321425986596
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# Obtaining metadata for ps stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321425986596
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-003.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# No metadata for this w stim experiment
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Obtaining metadata for none stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-002
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081322108325395
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
#
# Calculating frame ranges...
# ______________________________________________________________________
#
# Processing s2p data for pr experiment type
# ______________________________________________________________________
#
# loading 500 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  84
# ______________________________________________________________________
#
# Processing s2p data for ps experiment type
# ______________________________________________________________________
#
# loading 500 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  84
# ______________________________________________________________________
#
# No s2p data for w in this session
# ______________________________________________________________________
#
# ----------------------------------------------------------------
# Obtaining sham metadata for spont: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-002
# ----------------------------------------------------------------
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_NAPARM_002/2021-01-20_RL121_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL121/2021-01-20_RL121_t-002.paq
# total stim duration (frames): 4
# ______________________________________________________________________
#
# Processing s2p data for none experiment type
# ______________________________________________________________________
#
# loading 500 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  84
#
# ================================================================
# Fetching paths and stim types for: 2021-01-20_RL125
# ================================================================
#
# Umbrella folder: /home/rlees/mnt/qnap/Data/2021-01-20
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-002.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003.paq']
#
# Experimental sorted_paths = (array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003.paq'],
#       dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003.paq'],
#       dtype='<U70'), array([], dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-002.paq'],
#       dtype='<U70'))
#
# ----------------------------------------------------------------
# Obtaining metadata for pr stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321880879122
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# Obtaining metadata for ps stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321880879122
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-003.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# No metadata for this w stim experiment
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Obtaining metadata for none stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-002
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321653432857
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
#
# Calculating frame ranges...
# ______________________________________________________________________
#
# Processing s2p data for pr experiment type
# ______________________________________________________________________
#
# loading 450 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  68
# no S2 cells responding
# ______________________________________________________________________
#
# Processing s2p data for ps experiment type
# ______________________________________________________________________
#
# loading 450 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  68
# no S2 cells responding
# ______________________________________________________________________
#
# No s2p data for w in this session
# ______________________________________________________________________
#
# ----------------------------------------------------------------
# Obtaining sham metadata for spont: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-002
# ----------------------------------------------------------------
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_NAPARM_002/2021-01-20_RL125_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL125/2021-01-20_RL125_t-002.paq
# total stim duration (frames): 4
# ______________________________________________________________________
#
# Processing s2p data for none experiment type
# ______________________________________________________________________
#
# loading 450 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  68
# no S2 cells responding
#
# ================================================================
# Fetching paths and stim types for: 2021-01-20_RL124
# ================================================================
#
# Umbrella folder: /home/rlees/mnt/qnap/Data/2021-01-20
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-002']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-002.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003']
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003.paq']
#
# Experimental sorted_paths = (array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003.paq'],
#       dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003.paq'],
#       dtype='<U70'), array([], dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-002',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003',
#        '/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-002.paq'],
#       dtype='<U70'))
#
# ----------------------------------------------------------------
# Obtaining metadata for pr stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321198540344
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# Obtaining metadata for ps stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321198540344
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-003.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# No metadata for this w stim experiment
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Obtaining metadata for none stim: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-002
# ----------------------------------------------------------------
# n planes: 1
# n frames: 23075
# last good frame (0 = all good): 0
# fps: 15.081321880879122
# frame size (px): 1024 x 1024
# zoom: 2.0
# pixel size (um): 0.565169893755684 0.565169893755684
# scan centre (V): 0.0 0.0
#
# Calculating frame ranges...
# ______________________________________________________________________
#
# Processing s2p data for pr experiment type
# ______________________________________________________________________
#
# loading 505 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  70
# ______________________________________________________________________
#
# Processing s2p data for ps experiment type
# ______________________________________________________________________
#
# loading 505 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  70
# ______________________________________________________________________
#
# No s2p data for w in this session
# ______________________________________________________________________
#
# ----------------------------------------------------------------
# Obtaining sham metadata for spont: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-002
# ----------------------------------------------------------------
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_NAPARM_003/2021-01-20_RL124_NAPARM_003.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-20/RL124/2021-01-20_RL124_t-002.paq
# total stim duration (frames): 4
# ______________________________________________________________________
#
# Processing s2p data for none experiment type
# ______________________________________________________________________
#
# loading 505 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 23
# searching for targeted cells...
# search completed.
# Number of targeted cells:  70
#
# ================================================================
# Fetching paths and stim types for: 2021-01-28_RL124
# ================================================================
#
# Umbrella folder: /home/rlees/mnt/qnap/Data/2021-01-28
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-003']
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-003.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004']
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004.paq']
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004']
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002']
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004.paq']
#
# Experimental sorted_paths = (array(['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004',
#        '/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004.paq'],
#       dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004',
#        '/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004.paq'],
#       dtype='<U70'), array([], dtype='<U70'), array(['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-003',
#        '/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002',
#        '/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-003.paq'],
#       dtype='<U70'))
#
# ----------------------------------------------------------------
# Obtaining metadata for pr stim: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004
# ----------------------------------------------------------------
# n planes: 1
# n frames: 22986
# last good frame (0 = all good): 0
# fps: 15.023206948701938
# frame size (px): 1024 x 1024
# zoom: 0.834340962
# pixel size (um): 1.3547696193674 1.3547696193674
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 2
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004.paq
# total stim duration (frames): 6
#
# ----------------------------------------------------------------
# Obtaining metadata for ps stim: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004
# ----------------------------------------------------------------
# n planes: 1
# n frames: 22986
# last good frame (0 = all good): 0
# fps: 15.023206948701938
# frame size (px): 1024 x 1024
# zoom: 0.834340962
# pixel size (um): 1.3547696193674 1.3547696193674
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 2
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-004.paq
# total stim duration (frames): 6
#
# ----------------------------------------------------------------
# No metadata for this w stim experiment
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Obtaining metadata for none stim: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-003
# ----------------------------------------------------------------
# n planes: 1
# n frames: 22986
# last good frame (0 = all good): 0
# fps: 15.023206497308458
# frame size (px): 1024 x 1024
# zoom: 0.834340962
# pixel size (um): 1.3547696193674 1.3547696193674
# scan centre (V): 0.0 0.0
#
# Calculating frame ranges...
# ______________________________________________________________________
#
# Processing s2p data for pr experiment type
# ______________________________________________________________________
#
# loading 2300 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 27
# searching for targeted cells...
# search completed.
# Number of targeted cells:  55
# ______________________________________________________________________
#
# Processing s2p data for ps experiment type
# ______________________________________________________________________
#
# loading 2300 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 27
# searching for targeted cells...
# search completed.
# Number of targeted cells:  55
# ______________________________________________________________________
#
# No s2p data for w in this session
# ______________________________________________________________________
#
# ----------------------------------------------------------------
# Obtaining sham metadata for spont: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-003
# ----------------------------------------------------------------
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 2
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_NAPARM_002/2021-01-28_RL124_NAPARM_002.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2021-01-28/RL124/2021-01-28_RL124_t-003.paq
# total stim duration (frames): 6
# ______________________________________________________________________
#
# Processing s2p data for none experiment type
# ______________________________________________________________________
#
# loading 2300 traces labelled as cells
# subtracting neuropil with a coefficient of 0.7
# finding trials
# finding trials
#
# Finding SLM target locations...
# number of targets: 27
# searching for targeted cells...
# search completed.
# Number of targeted cells:  55
