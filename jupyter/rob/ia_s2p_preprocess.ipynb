# %% [markdown]
# ## Notebook for collecting metadata, processing imaging data through suite2p and analysing trial responses

# %%
# %run ./rob_setup_notebook.ipynb

import utils.interareal_analysis as ia
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Suite2p path: ['/home/rlees/anaconda3/envs/suite2p/lib/python3.7/site-packages/suite2p']
# qnap_path: /home/rlees/mnt/qnap
# qnap_data_path /home/rlees/mnt/qnap/Data
# pkl_folder: /home/rlees/mnt/qnap/pkl_files
# master_path: /home/rlees/mnt/qnap/master_pkl/master_obj.pkl
# fig_save_path: /home/rlees/mnt/qnap/Analysis/Figures
# stam_save_path: /home/rlees/mnt/qnap/Analysis/STA_movies
# s2_borders_path: /home/rlees/mnt/qnap/Analysis/S2_borders

# %% [markdown]
# ### Define sessions to run s2p or analysis on

# %%
ss_id = '1PgSXs6BVHe9dACWEydykucN74rirNfOY4Vr_AmLcCdY'
sheet_names = [
#     '2019-06-11_J048',
#     '2019-06-13_J052',
#     '2019-06-25_RL048',
#     '2019-07-15_RL052',
#     '2019-08-14_J058',
#     '2019-08-14_J059',
#     '2019-08-15_RL055',
#     '2019-11-14_J061',
#     '2019-11-14_J063',
#     '2019-11-15_J064',
#     '2019-11-18_J065',
#     '2020-02-27_RL075',
#     '2020-03-03_RL074',
#     '2020-03-05_RL070',
#     '2020-03-05_RL072',
#     '2020-03-12_RL070',
#     '2020-03-16_RL074',
#     '2020-03-19_RL075',
#     '2020-06-03_RL086',
#     '2020-06-08_RL086',
#     '2020-06-15_RL086',
#     '2020-09-03_RL091',
#     '2020-09-04_RL093',
#     '2020-09-08_RL099',
#     '2020-09-09_RL100',
#     '2020-09-14_RL101',
#     '2020-09-15_RL102',
#     '2020-09-16_RL103',
#     '2020-10-02_RL108',
#     '2020-10-12_RL109',
#     '2020-10-29_RL111',
#     '2020-12-10_RL115',
#     '2021-01-06_RL120',
#     '2021-01-06_RL120_test',
#     '2021-01-20_RL121',
#     '2021-01-20_RL125', 
#     '2021-01-20_RL124', 
#     '2021-01-28_RL124', 
#     '2021-02-18_RL127', 
#     '2021-02-22_RL128', 
#     '2021-02-23_RL129', 
#     '2021-02-24_RL132', 
#     '2021-02-25_RL131', 
#     '2021-03-02_RL130',
    '2022-01-12_RL136',
    '2022-01-13_RL135',
    '2022-01-14_RL134',
    '2022-01-17_RL133'
              ]

# %% [markdown]
# ### Run s2p on defined sessions (commented-out to not overwrite data by accident)

# %%
# for sheet_name in sheet_names:
    
#     # Initialise the class
#     ses_obj = ia.interarealProcessing(ss_id, sheet_name, qnap_data_path)
    
#     # Run s2p on this experiment (if not already done)
#     ses_obj.s2pRun(tau=1.25) # tau = 0.7 for fast, 1.25 for slow
    
#     # Pickle the object output to save it for analysis
#     pkl_path = os.path.join(pkl_folder, sheet_name + '.pkl')
    
#     with open(pkl_path, 'wb') as f:
#         pickle.dump(ses_obj, f)
# Out:
# ================================================================
# Fetching paths and stim types for: 2022-01-12_RL136
# ================================================================
#
# Umbrella folder: /home/rlees/mnt/qnap/Data/2022-01-12
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-002']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-002.paq']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-004']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-004.paq']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-007']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_003']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-007.paq']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_005']
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008.paq']
#
# Experimental sorted_paths = (array(['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008',
#        '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_005',
#        '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008.paq'],
#       dtype='<U94'), array(['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-007',
#        '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_003',
#        '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-007.paq'],
#       dtype='<U94'), array(['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-002',
#        'none',
#        '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-002.paq'],
#       dtype='<U94'), array(['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-004',
#        'none',
#        '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-004.paq'],
#       dtype='<U94'))
#
# ----------------------------------------------------------------
# Obtaining metadata for pr stim: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008
# ----------------------------------------------------------------
# n planes: 1
# n frames: 22836
# last good frame (0 = all good): 0
# fps: 15.023206497308458
# frame size (px): 1024 x 1024
# zoom: 0.834340962
# pixel size (um): 1.3547696193674 1.3547696193674
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_005/2022-01-11_RL136_NAPARM_005.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_005/2022-01-11_RL136_NAPARM_005.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_005/2022-01-11_RL136_NAPARM_005.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_005/2022-01-11_RL136_NAPARM_005.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# Obtaining metadata for ps stim: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-007
# ----------------------------------------------------------------
# n planes: 1
# n frames: 22836
# last good frame (0 = all good): 0
# fps: 15.023206723005195
# frame size (px): 1024 x 1024
# zoom: 0.834340962
# pixel size (um): 1.3547696193674 1.3547696193674
# scan centre (V): 0.0 0.0
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_003/2022-01-11_RL136_NAPARM_003.xml']
#
# NAPARM xml: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_003/2022-01-11_RL136_NAPARM_003.xml
# numbers of trials: 100
# inter-group delay: 5
# number of groups: 1
# number of shots: 1
# number of sequence reps: 10
# single stim duration (ms): 10.0
# ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_003/2022-01-11_RL136_NAPARM_003.gpl']
#
# NAPARM gpl: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_NAPARM/2022-01-11_RL136_NAPARM_003/2022-01-11_RL136_NAPARM_003.gpl
#
# spiral size (um): 10
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-007.paq
# total stim duration (frames): 4
#
# ----------------------------------------------------------------
# Obtaining metadata for w stim: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-002
# ----------------------------------------------------------------
# n planes: 1
# n frames: 16977
# last good frame (0 = all good): 0
# fps: 15.023206271611729
# frame size (px): 1024 x 1024
# zoom: 0.834340962
# pixel size (um): 1.3547696193674 1.3547696193674
# scan centre (V): 0.0 0.0
#
# Finding stim frames from: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-002.paq
# total stim duration (frames): 17
#
# ----------------------------------------------------------------
# Obtaining metadata for none stim: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-004
# ----------------------------------------------------------------
# n planes: 1
# n frames: 22986
# last good frame (0 = all good): 0
# fps: 15.023206045915005
# frame size (px): 1024 x 1024
# zoom: 0.834340962
# pixel size (um): 1.3547696193674 1.3547696193674
# scan centre (V): 0.0 0.0
#
# s2p ops: {'data_path': ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008', '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-007', '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-002', '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-004'], 'fs': 15.023206497308458, 'diameter': (9, 9), 'nplanes': 1, 'tau': 1.25} {'look_one_level_down': False, 'delete_bin': True, 'mesoscan': False, 'h5py': [], 'h5py_key': 'data', 'save_path0': [], 'fast_disk': '/mnt/sandbox/rlees/temp_suite2p_binaries', 'subfolders': [], 'nplanes': 1, 'nchannels': 1, 'functional_chan': 1, 'tau': 1.25, 'fs': 30.0, 'force_sktiff': False, 'preclassify': 0, 'save_mat': False, 'combined': False, 'aspect': 1.0, 'num_workers': 0, 'num_workers_roi': 0, 'do_bidiphase': False, 'bidiphase': 0, 'do_registration': 1, 'keep_movie_raw': False, 'nimg_init': 500, 'batch_size': 1000, 'maxregshift': 0.1, 'align_by_chan': 1, 'reg_tif': False, 'reg_tif_chan2': False, 'subpixel': 10, 'smooth_sigma': 1.15, 'th_badframes': 1.0, 'pad_fft': False, 'nonrigid': False, 'block_size': [128, 128], 'snr_thresh': 1.2, 'maxregshiftNR': 5, '1Preg': False, 'spatial_hp': 50, 'pre_smooth': 2, 'spatial_taper': 50, 'roidetect': True, 'sparse_mode': False, 'spatial_scale': 0, 'connected': True, 'nbinned': 5000, 'max_iterations': 30, 'threshold_scaling': 0.4, 'max_overlap': 0.9, 'high_pass': 100, 'smooth_masks': True, 'inner_neuropil_radius': 2, 'min_neuropil_pixels': 350, 'allow_overlap': False, 'chan2_thres': 0.65, 'baseline': 'maximin', 'win_baseline': 60.0, 'sig_baseline': 10.0, 'prctile_baseline': 8.0, 'neucoeff': 0.7, 'xrange': array([0, 0]), 'yrange': array([0, 0])}
# {'data_path': ['/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008', '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-007', '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-002', '/home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-004'], 'fs': 15.023206497308458, 'diameter': (9, 9), 'nplanes': 1, 'tau': 1.25}
# tif
# ** Found 4 tifs - converting to binary **
# 4000 frames of binary, time 61.27 sec.
# 8000 frames of binary, time 117.42 sec.
# 12000 frames of binary, time 169.43 sec.
# 16000 frames of binary, time 221.16 sec.
# 20000 frames of binary, time 278.06 sec.
# time 1132.40 sec. Wrote 85635 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 85635 frames
# Reference frame, 164.04 sec.
# Registered 4000/85635 in 213.72s
# Registered 8000/85635 in 433.34s
# Registered 12000/85635 in 657.88s
# Registered 16000/85635 in 873.76s
# Registered 20000/85635 in 1098.19s
# Registered 24000/85635 in 1325.74s
# Registered 28000/85635 in 1583.32s
# Registered 32000/85635 in 1831.48s
# Registered 36000/85635 in 2058.30s
# Registered 40000/85635 in 2280.97s
# Registered 44000/85635 in 2502.97s
# Registered 48000/85635 in 2720.87s
# Registered 52000/85635 in 2943.34s
# Registered 56000/85635 in 3180.37s
# Registered 60000/85635 in 3405.55s
# Registered 64000/85635 in 3623.08s
# Registered 68000/85635 in 3843.14s
# Registered 72000/85635 in 4070.03s
# Registered 76000/85635 in 4289.46s
# Registered 80000/85635 in 4518.38s
# Registered 84000/85635 in 4735.51s
# bad frames file path: /home/rlees/mnt/qnap/Data/2022-01-12/RL136/2022-01-12_RL136_t-008/bad_frames.npy
# number of badframes: 1000
# ----------- Total 4992.97 sec
# Registration metrics, 65.50 sec.
# NOTE: Applying builtin classifier at /home/rlees/anaconda3/envs/suite2p/lib/python3.7/site-packages/suite2p/classifiers/classifier.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 19
# Binned movie [4357,1012,1016], 811.47 sec.
# ROIs: 200, cost: 0.6315, time: 305.0738
# ROIs: 400, cost: 0.6120, time: 402.4824
# ROIs: 600, cost: 0.6006, time: 500.9237
# ROIs: 800, cost: 0.5929, time: 603.8467
# ROIs: 1000, cost: 0.5871, time: 714.8318
# ROIs: 1200, cost: 0.5821, time: 826.1748
# ROIs: 1400, cost: 0.5779, time: 938.5017
# ROIs: 1600, cost: 0.5739, time: 1055.7477
# ROIs: 1800, cost: 0.5701, time: 1177.5119
# ROIs: 2000, cost: 0.5666, time: 1302.6636
# ROIs: 2200, cost: 0.5634, time: 1430.8171
# ROIs: 2400, cost: 0.5604, time: 1564.5530
# ROIs: 2600, cost: 0.5575, time: 1699.7754
# ROIs: 2800, cost: 0.5548, time: 1840.1464
# ROIs: 3000, cost: 0.5521, time: 1984.4862
# ROIs: 3200, cost: 0.5496, time: 2133.8627
# ROIs: 3400, cost: 0.5472, time: 2286.6543
# ROIs: 3600, cost: 0.5448, time: 2443.6576
# ROIs: 3800, cost: 0.5426, time: 2607.5434
# ROIs: 4000, cost: 0.5403, time: 2775.0085
# ROIs: 4200, cost: 0.5381, time: 2947.3158
# ROIs: 4400, cost: 0.5360, time: 3122.1383
# ROIs: 4550, cost: 0.5344, time: 3300.1877
# ROIs: 4574, cost: 0.5341, time: 3475.1529
# ROIs: 4585, cost: 0.5339, time: 3650.9874
# ROIs: 4585, cost: 0.5748, time: 3846.3279
# ROIs: 4585, cost: 0.5487, time: 3940.4260
# ROIs: 4585, cost: 0.5477, time: 4017.9733
# Found 4585 ROIs, 4108.28 sec
# After removing overlaps, 4551 ROIs remain
# Masks made in 108.32 sec.
# ----------- Total 5031.41 sec.
# ----------- EXTRACTION

# %% [markdown]
# ### Run sessions through preprocessing pipeline (after s2p ROI curation and s2 border created)

# %%
trial_sig_calc = 'dff' # how to calculate trial significance ('dff' or 'dfsf' = change in f over std deviation of f)
prestim_sec = 2
poststim_sec = 10
test_sec = 1.5

for sheet_name in sheet_names:
    
    # Initialise the class
    ses_obj = ia.interarealProcessing(ss_id, sheet_name, qnap_data_path)
    
    # Get the range of frames that are attributed to each experiment (from the concatenated t-series)
    ses_obj.getFrameRanges()
    
    # Process the s2p data (after manual curation)
    ses_obj.photostim_r.s2pAnalysis(s2_borders_path, prestim_sec, poststim_sec, test_sec, trial_sig_calc)
    ses_obj.photostim_s.s2pAnalysis(s2_borders_path, prestim_sec, poststim_sec, test_sec, trial_sig_calc)
    ses_obj.whisker_stim.s2pAnalysis(s2_borders_path, prestim_sec, poststim_sec, test_sec, trial_sig_calc)
    
    # Add sham photostim metadata
    if ses_obj.spont.n_frames > 0:
        ses_obj.addShamPhotostim()
        
    ses_obj.spont.s2pAnalysis(s2_borders_path, prestim_sec, poststim_sec, test_sec, trial_sig_calc)
    
    ses_obj.whiskerTargets()
    
    # Pickle the object output to save it for analysis
    pkl_path = os.path.join(pkl_folder, sheet_name + '.pkl')
    
    with open(pkl_path, 'wb') as f:
        pickle.dump(ses_obj, f)
