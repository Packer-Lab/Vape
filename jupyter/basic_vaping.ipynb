# %%
# %run ./setup_notebook.ipynb  # Change path in setup_notebook if needed
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

# %%
sys.path.append('/home/jamesrowland/Documents/Code/Vape/utils')
import utils_funcs as uf

# %%
s2p_path = '/home/jamesrowland/Documents/packerstation/jrowland/Data/2019-08-03/2019-08-03_J048_t-003/suite2p/plane0'

flu, spks, stat = uf.s2p_loader(s2p_path)
# Out:
# Loading 761 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7

# %%
len(stat)
# Out:
# 761

# %%
s0 = stat[0]

# %%
for k, v in s0.items():
    print(k)
# Out:
# ypix
# lam
# xpix
# mrs
# mrs0
# compact
# med
# npix
# footprint
# npix_norm
# overlap
# ipix
# radius
# aspect_ratio
# skew
# std
# original_index

# %%
flu.shape
# Out:
# (761, 18064)

# %%
plt.figure(figsize=(50,30))
for i in range(12):
    plt.subplot(4,3,i+1)
    plt.plot(flu[i,:])
